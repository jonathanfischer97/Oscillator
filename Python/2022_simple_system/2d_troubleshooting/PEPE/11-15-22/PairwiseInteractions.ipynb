# %%
import itertools

# %%
species = ['LpATM','M','D','T']
# species = ['LpAT','M']

# %%
list(itertools.combinations(species,2))
# Out:
# [('LpATM', 'M'),
#  ('LpATM', 'D'),
#  ('LpATM', 'T'),
#  ('M', 'D'),
#  ('M', 'T'),
#  ('D', 'T')]

# %%
species = ['LpATM','M','D','T']
size = 0
for i in range(2):

    for pair in itertools.combinations(species,2):
        newspecies = pair[0] + pair[1]
        if newspecies not in species:
            species.append(newspecies)

# %%
species
# Out:
# ['LpATM',
#  'M',
#  'D',
#  'T',
#  'LpATMM',
#  'LpATMD',
#  'LpATMT',
#  'MD',
#  'MT',
#  'DT',
#  'LpATMLpATMM',
#  'LpATMLpATMD',
#  'LpATMLpATMT',
#  'LpATMMD',
#  'LpATMMT',
#  'LpATMDT',
#  'MLpATMM',
#  'MLpATMD',
#  'MLpATMT',
#  'MMD',
#  'MMT',
#  'MDT',
#  'DLpATMM',
#  'DLpATMD',
#  'DLpATMT',
#  'DMD',
#  'DMT',
#  'DDT',
#  'TLpATMM',
#  'TLpATMD',
#  'TLpATMT',
#  'TMD',
#  'TMT',
#  'TDT',
#  'LpATMMLpATMD',
#  'LpATMMLpATMT',
#  'LpATMMMD',
#  'LpATMMMT',
#  'LpATMMDT',
#  'LpATMDLpATMT',
#  'LpATMDMD',
#  'LpATMDMT',
#  'LpATMDDT',
#  'LpATMTMD',
#  'LpATMTMT',
#  'LpATMTDT',
#  'MDMT',
#  'MDDT',
#  'MTDT']

# %%
list(itertools.product(species,repeat=10))
# Out:
# [('LpAT',
#   'LpAT',
#   'LpAT',
#   'LpAT',
#   'LpAT',
#   'LpAT',
#   'LpAT',
#   'LpAT',
#   'LpAT',
#   'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'M', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'M', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'M', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'M', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'M', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'M', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'M', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'M', 'M', 'M'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'M'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'M'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'M'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'M'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'M', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'M', 'M', 'M'),
#  ('LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M'),
#  ('LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M'),
#  ('LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M'),
#  ('LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M'),
#  ('LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M'),
#  ('LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M'),
#  ('LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M'),
#  ('LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'M', 'M', 'M'),
#  ('LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M'),
#  ('LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M'),
#  ('LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M'),
#  ('LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'M', 'M', 'M'),
#  ('LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M'),
#  ('LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'M', 'M', 'M'),
#  ('LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'M', 'LpAT', 'M', 'M'),
#  ('LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'M', 'M', 'LpAT', 'M'),
#  ('LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'LpAT'),
#  ('LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'M'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'M'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'M'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'M'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'M'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'M', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'M', 'M'),
#  ('LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M'),
#  ('LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M'),
#  ('LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M'),
#  ('LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M'),
#  ('LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M'),
#  ('LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M'),
#  ('LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M'),
#  ('LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M'),
#  ('LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M'),
#  ('LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M'),
#  ('LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M'),
#  ('LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'M', 'M'),
#  ('LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M'),
#  ('LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M'),
#  ('LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M'),
#  ('LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M'),
#  ('LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M'),
#  ('LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'M', 'M'),
#  ('LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M'),
#  ('LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M'),
#  ('LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'M', 'M'),
#  ('LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'M', 'M'),
#  ('LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'M', 'M', 'LpAT', 'M'),
#  ('LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'M', 'M', 'M', 'LpAT'),
#  ('LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'M', 'M', 'M', 'M'),
#  ('LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M'),
#  ('LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M'),
#  ('LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT'),
#  ('LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M'),
#  ('LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M'),
#  ('LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M'),
#  ('LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT'),
#  ('LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M'),
#  ('LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M'),
#  ('LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M'),
#  ('LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT'),
#  ('LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M'),
#  ('LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M'),
#  ('LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M'),
#  ('LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT'),
#  ('LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'M'),
#  ('LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M'),
#  ('LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M'),
#  ('LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT'),
#  ('LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M'),
#  ('LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M'),
#  ('LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M'),
#  ('LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT'),
#  ('LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'M'),
#  ('LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M'),
#  ('LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M'),
#  ('LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT'),
#  ('LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'M'),
#  ('LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'M'),
#  ('LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'M'),
#  ('LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'M', 'M', 'M', 'LpAT'),
#  ('LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'M', 'M', 'M', 'M'),
#  ('LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M'),
#  ('LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M'),
#  ('LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT'),
#  ('LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M'),
#  ('LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M'),
#  ('LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M'),
#  ('LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT'),
#  ('LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M'),
#  ('LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M'),
#  ('LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M'),
#  ('LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT'),
#  ('LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M'),
#  ('LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M'),
#  ('LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M'),
#  ('LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT'),
#  ('LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'M', 'M', 'M', 'M'),
#  ('LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M'),
#  ('LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M'),
#  ('LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT'),
#  ('LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M'),
#  ('LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M'),
#  ('LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M'),
#  ('LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT'),
#  ('LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'M', 'M', 'M', 'M'),
#  ('LpAT', 'M', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'M', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'M', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M'),
#  ('LpAT', 'M', 'M', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'M', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M'),
#  ('LpAT', 'M', 'M', 'M', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT'),
#  ('LpAT', 'M', 'M', 'M', 'M', 'M', 'LpAT', 'M', 'M', 'M'),
#  ('LpAT', 'M', 'M', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'M', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M'),
#  ('LpAT', 'M', 'M', 'M', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT'),
#  ('LpAT', 'M', 'M', 'M', 'M', 'M', 'M', 'LpAT', 'M', 'M'),
#  ('LpAT', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT'),
#  ('LpAT', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'LpAT', 'M'),
#  ('LpAT', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'LpAT'),
#  ('LpAT', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'M'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'M'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'M'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'M'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'M'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'M', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'M', 'M'),
#  ('M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M'),
#  ('M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M'),
#  ('M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M'),
#  ('M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M'),
#  ('M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M'),
#  ('M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M'),
#  ('M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M'),
#  ('M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M'),
#  ('M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M'),
#  ('M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M'),
#  ('M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M'),
#  ('M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M'),
#  ('M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M'),
#  ('M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'M', 'M'),
#  ('M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M'),
#  ('M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M'),
#  ('M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M'),
#  ('M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M'),
#  ('M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M'),
#  ('M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M'),
#  ('M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'M', 'M'),
#  ('M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M'),
#  ('M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M'),
#  ('M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'M', 'M'),
#  ('M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M'),
#  ('M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'M', 'M'),
#  ('M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'M', 'LpAT', 'M'),
#  ('M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'M', 'M', 'LpAT'),
#  ('M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'M', 'M', 'M'),
#  ('M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M'),
#  ('M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M'),
#  ('M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT'),
#  ('M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M'),
#  ('M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M'),
#  ('M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT'),
#  ('M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M'),
#  ('M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT'),
#  ('M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M'),
#  ('M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT'),
#  ('M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M'),
#  ('M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M'),
#  ('M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M'),
#  ('M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT'),
#  ('M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M'),
#  ('M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M'),
#  ('M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT'),
#  ('M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M'),
#  ('M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT'),
#  ('M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M'),
#  ('M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT'),
#  ('M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'M'),
#  ('M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M'),
#  ('M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M'),
#  ('M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT'),
#  ('M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M'),
#  ('M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M'),
#  ('M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT'),
#  ('M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M'),
#  ('M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT'),
#  ('M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M'),
#  ('M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT'),
#  ('M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'M'),
#  ('M', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M'),
# ...
#  ('M', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('M', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M'),
#  ('M', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT'),
#  ('M', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'M', 'M', 'M'),
#  ('M', 'LpAT', 'M', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'LpAT', 'M', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M'),
#  ('M', 'LpAT', 'M', 'M', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT'),
#  ('M', 'LpAT', 'M', 'M', 'M', 'M', 'M', 'LpAT', 'M', 'M'),
#  ('M', 'LpAT', 'M', 'M', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT'),
#  ('M', 'LpAT', 'M', 'M', 'M', 'M', 'M', 'M', 'LpAT', 'M'),
#  ('M', 'LpAT', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'LpAT'),
#  ('M', 'LpAT', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M'),
#  ('M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M'),
#  ('M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M'),
#  ('M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT'),
#  ('M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M'),
#  ('M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M'),
#  ('M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT'),
#  ('M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M'),
#  ('M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT'),
#  ('M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M'),
#  ('M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT'),
#  ('M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M'),
#  ('M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M'),
#  ('M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M'),
#  ('M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT'),
#  ('M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M'),
#  ('M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M'),
#  ('M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT'),
#  ('M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M'),
#  ('M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT'),
#  ('M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M'),
#  ('M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT'),
#  ('M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'M'),
#  ('M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M'),
#  ('M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M'),
#  ('M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT'),
#  ('M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M'),
#  ('M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M'),
#  ('M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT'),
#  ('M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M'),
#  ('M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT'),
#  ('M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M'),
#  ('M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT'),
#  ('M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'M'),
#  ('M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M'),
#  ('M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M'),
#  ('M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT'),
#  ('M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'M'),
#  ('M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M'),
#  ('M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT'),
#  ('M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'M'),
#  ('M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT'),
#  ('M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'M'),
#  ('M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'M', 'LpAT'),
#  ('M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'M', 'M'),
#  ('M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M'),
#  ('M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M'),
#  ('M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT'),
#  ('M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M'),
#  ('M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M'),
#  ('M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT'),
#  ('M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M'),
#  ('M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT'),
#  ('M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M'),
#  ('M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT'),
#  ('M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M'),
#  ('M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M'),
#  ('M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M'),
#  ('M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT'),
#  ('M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M'),
#  ('M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M'),
#  ('M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT'),
#  ('M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M'),
#  ('M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT'),
#  ('M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M'),
#  ('M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT'),
#  ('M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'M', 'M'),
#  ('M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M'),
#  ('M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M'),
#  ('M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT'),
#  ('M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M'),
#  ('M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M'),
#  ('M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT'),
#  ('M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M'),
#  ('M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT'),
#  ('M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M'),
#  ('M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT'),
#  ('M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'M', 'M'),
#  ('M', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('M', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('M', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M'),
#  ('M', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('M', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M'),
#  ('M', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT'),
#  ('M', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'M', 'M'),
#  ('M', 'M', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'M', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M'),
#  ('M', 'M', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT'),
#  ('M', 'M', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'M', 'M'),
#  ('M', 'M', 'LpAT', 'M', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT'),
#  ('M', 'M', 'LpAT', 'M', 'M', 'M', 'M', 'M', 'LpAT', 'M'),
#  ('M', 'M', 'LpAT', 'M', 'M', 'M', 'M', 'M', 'M', 'LpAT'),
#  ('M', 'M', 'LpAT', 'M', 'M', 'M', 'M', 'M', 'M', 'M'),
#  ('M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M'),
#  ('M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M'),
#  ('M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT'),
#  ('M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M'),
#  ('M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M'),
#  ('M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT'),
#  ('M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M'),
#  ('M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT'),
#  ('M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M'),
#  ('M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT'),
#  ('M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M'),
#  ('M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M'),
#  ('M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M'),
#  ('M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT'),
#  ('M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M'),
#  ('M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M'),
#  ('M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT'),
#  ('M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M'),
#  ('M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT'),
#  ('M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M'),
#  ('M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT'),
#  ('M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M', 'M'),
#  ('M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M'),
#  ('M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M'),
#  ('M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT'),
#  ('M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M'),
#  ('M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M'),
#  ('M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT'),
#  ('M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M'),
#  ('M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT'),
#  ('M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M'),
#  ('M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT'),
#  ('M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M', 'M'),
#  ('M', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('M', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('M', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M'),
#  ('M', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('M', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M'),
#  ('M', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT'),
#  ('M', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M', 'M'),
#  ('M', 'M', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'M', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M'),
#  ('M', 'M', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT'),
#  ('M', 'M', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M', 'M'),
#  ('M', 'M', 'M', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT'),
#  ('M', 'M', 'M', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT', 'M'),
#  ('M', 'M', 'M', 'LpAT', 'M', 'M', 'M', 'M', 'M', 'LpAT'),
#  ('M', 'M', 'M', 'LpAT', 'M', 'M', 'M', 'M', 'M', 'M'),
#  ('M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M', 'M'),
#  ('M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT', 'M'),
#  ('M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'LpAT'),
#  ('M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M', 'M'),
#  ('M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT', 'M'),
#  ('M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'LpAT'),
#  ('M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M', 'M'),
#  ('M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'LpAT'),
#  ('M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT', 'M'),
#  ('M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'LpAT'),
#  ('M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M', 'M'),
#  ('M', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('M', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('M', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'LpAT', 'M', 'M'),
#  ('M', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('M', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'LpAT', 'M'),
#  ('M', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M', 'LpAT'),
#  ('M', 'M', 'M', 'M', 'LpAT', 'M', 'LpAT', 'M', 'M', 'M'),
#  ('M', 'M', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'M', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'LpAT', 'M'),
#  ('M', 'M', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M', 'LpAT'),
#  ('M', 'M', 'M', 'M', 'LpAT', 'M', 'M', 'LpAT', 'M', 'M'),
#  ('M', 'M', 'M', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT', 'LpAT'),
#  ('M', 'M', 'M', 'M', 'LpAT', 'M', 'M', 'M', 'LpAT', 'M'),
#  ('M', 'M', 'M', 'M', 'LpAT', 'M', 'M', 'M', 'M', 'LpAT'),
#  ('M', 'M', 'M', 'M', 'LpAT', 'M', 'M', 'M', 'M', 'M'),
#  ('M', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'LpAT'),
#  ('M', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'LpAT', 'M'),
#  ('M', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'LpAT'),
#  ('M', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'LpAT', 'M', 'M'),
#  ('M', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'LpAT'),
#  ('M', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'LpAT', 'M'),
#  ('M', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'LpAT'),
#  ('M', 'M', 'M', 'M', 'M', 'LpAT', 'LpAT', 'M', 'M', 'M'),
#  ...]

# %%
def product(*args, repeat=1):
    # product('ABCD', 'xy') --> Ax Ay Bx By Cx Cy Dx Dy
    # product(range(2), repeat=3) --> 000 001 010 011 100 101 110 111
    pools = [tuple(pool) for pool in args] * repeat
    result = [[]]
    for pool in pools:
        result = [x+[y] for x in result for y in pool]
    for prod in result:
        yield tuple(prod)

# %%
for mol in species:

# %%
pools
# Out:
# [('L', 'p', 'A', 'T', 'M'),
#  ('M',),
#  ('D',),
#  ('T',),
#  ('L', 'p', 'A', 'T', 'M'),
#  ('M',),
#  ('D',),
#  ('T',),
#  ('L', 'p', 'A', 'T', 'M'),
#  ('M',),
#  ('D',),
#  ('T',),
#  ('L', 'p', 'A', 'T', 'M'),
#  ('M',),
#  ('D',),
#  ('T',)]
